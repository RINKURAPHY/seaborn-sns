# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Placement_Data.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
print("The number of row:",dataset.shape[0])
print("The number of column:",dataset.shape[1])
# Out:
# The number of row: 215
# The number of column: 15

# %%
import seaborn as sb
import matplotlib.pyplot as plt

sb.histplot(dataset['ssc_p'], kde=True, color='red')
# Out:
# <AxesSubplot:xlabel='ssc_p', ylabel='Count'>

# %%
print(dataset[['ssc_p', 'salary']].dtypes)
print(dataset[['ssc_p', 'salary']].head())
# Out:
# ssc_p     float64
# salary    float64
# dtype: object
#    ssc_p    salary
# 0  67.00  270000.0
# 1  79.33  200000.0
# 2  65.00  250000.0
# 3  56.00       NaN
# 4  85.80  425000.0

# %%
dataset['ssc_p'] = pd.to_numeric(dataset['ssc_p'], errors='coerce')
dataset['salary'] = pd.to_numeric(dataset['salary'], errors='coerce')

# %%
dataset = dataset.dropna(subset=['ssc_p', 'salary'])

# %%
import seaborn as sns
import pandas as pd
import numpy as np

print(sns.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 0.12.2
# 1.3.5
# 1.21.6

# %%
# !pip install seaborn --upgrade
# !pip install pandas --upgrade
# !pip install numpy --upgrade

# %%
pip install pandas --upgrade --user
# Out:
# ...
#
# ...

# %%
pip show pandas
# Out:
# Name: pandasNote: you may need to restart the kernel to use updated packages.
#
# Version: 1.3.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: c:\users\jose\anaconda3\envs\aiml\lib\site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: seaborn, statsmodels

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='ssc_p', y='salary', data=dataset,kind='scatter')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='ssc_p', y='salary', data=dataset,kind='hex')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='ssc_p', y='salary', data=dataset,kind='kde')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='ssc_p', y='salary', data=dataset,kind='hist')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='ssc_p', y='salary', data=dataset,kind='reg')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='ssc_p', y='salary', data=dataset,kind='resid')
plt.show()

# %%
sns.pairplot(dataset, hue='gender',diag_kind='kde',kind='scatter',palette='husl')
plt.show()

# %%
sns.violinplot(x='ssc_p', y='salary', data=dataset)
plt.show()

# %%
sns.violinplot(x='gender', y='ssc_p', data=dataset,)
plt.show()

# %%
sns.violinplot(x='specialisation', y='salary', data=dataset,hue='gender')
plt.show()

# %%
sns.violinplot(x='specialisation', y='salary', data=dataset)
plt.show()

# %%
sns.barplot(x='specialisation', y='salary', data=dataset,hue='gender')
plt.show()

# %%
sns.boxplot(x='ssc_b', y='ssc_p', data=dataset)
plt.show()

# %%
sns.boxplot(x='ssc_b', y='ssc_p', data=dataset,hue='gender')
plt.show()
